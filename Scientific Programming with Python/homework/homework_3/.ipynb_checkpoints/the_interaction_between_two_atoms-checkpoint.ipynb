# %% [markdown]
# ## SciPro ID: 2026SS_07

# %% [markdown]
# # Homework_3: The Interaction Between Two Atoms

# %% [markdown]
# ***

# %% [markdown]
# ### Imports:

# %%
import pandas as pd

# %% [markdown]
# ***

# %% [markdown]
# ### Task 1:
# The goal of this task is to load the QM target data for $Ar_2$ into a Pandas DataFrame and prepare it for the the following calculations.
#
# The input file `CybulskiT19999_Ar2.csv` contains the distances in Angstrom and the energies, in Hartree, which Cybulski and Toczyłowski determined using quantum mechanics (QM).$^{[1]}$
#
# The data is cleaned by removing duplicate rows and rows with missing values.

# %%
input_data = pd.read_csv('CybulskiT1999_Ar2.csv', header=0, sep=';')

ar2_calculations = input_data.dropna()
ar2_calculations = ar2_calculations.drop_duplicates()

# %% [markdown]
# The potential energies given are originally in Hartree and have to be converted to kJ/mol using the following formula:
#
# $$E_{kJ/mol} = E_{Hartree} \cdot 2625.5^{[2]}$$
# where:
# - $E_{kJ/mol}$ is the converted potential energy in **kilojoules per mole**
# - $E_{Hartree}$ is the QM energy in **Hartree**

# %%
ar2_calculations["QM V(r) (kJ/mol)"] = ar2_calculations["QM V(r) (Hartree)"] * 2625.5

ar2_calculations
# Out:
#     R (Å)  QM V(r) (Hartree)  QM V(r) (kJ/mol)
# 2   3.000           0.003055          8.020850
# 3   3.250           0.000518          1.360298
# 4   3.500          -0.000279         -0.732462
# 5   3.750          -0.000441         -1.157373
# 7   3.775          -0.000442         -1.160130
# 8   3.800          -0.000441         -1.158686
# 9   3.850          -0.000436         -1.145269
# 10  4.000          -0.000400         -1.049150
# 11  4.250          -0.000313         -0.822097
# 13  4.500          -0.000232         -0.609904
# 14  5.000          -0.000123         -0.322831
# 17  6.000          -0.000038         -0.099165
# 18  7.000          -0.000014         -0.036836

# %% [markdown]
# The resulting table contains the cleaned distances, the original QM energies in Hartree, and the converted energies in kJ/mol. These values are used as the reference data for the Lennard-Jones calculation and the later visualization.

# %% [markdown]
# ***

# %% [markdown]
# ### Task 2:
# The goal of this task is to calculate the Lennard-Jones potential energy for the same distances that are used in the QM target data.
#
# For this we will use following equation:
# $$
#  V_{LJ}(r) = 4\epsilon \left[  (\frac{\sigma}{r})^{12} - (\frac{\sigma}{r})^6\right]^{[3]}
# $$
# where:
# - $V_{LJ}(r)$ is the Lennard-Jones potential energy in **kJ/mol**,
# - $epsilon$ is the energy well depth in **kJ/mol**,
# - $sigma$ is the distance where the potential energy becomes zero in **Å**,
# - $r$ is the actual distance between the two Argon atoms in **Å**.
#
# The Argon parameters used here are literature values originally given in ergs and cm and have been converted to more modern units:$^{[4]}$
# - $\epsilon$ = 0.995 kJ/mol,
# - $\sigma$ = 3.405 Å.

# %%
def lennard_jones(epsilon, sigma, r):
    ''' doc string and isinstance and typeending incoming '''
    return(4 * epsilon * ((sigma/r)**12 - (sigma/r)**6))

# %% [markdown]
# The user-defined function is applied to each distance value in the DataFrame. The resulting Lennard-Jones energies are collected in a list.

# %%
epsilon = 0.995
sigma = 3.405
lj_energies = []

for index, row in ar2_calculations.iterrows():
    lj_energies.append(lennard_jones(epsilon, sigma, row.iloc[0]))

# %% [markdown]
# The calculated Lennard-Jones energies are added to the DataFrame as a new column `Lennard-Jones V(r) (kJ/mol)`

# %%
ar2_calculations['Lennard-Jones V(r) (kJ/mol)'] = lj_energies
ar2_calculations
# Out:
#     R (Å)  QM V(r) (Hartree)  QM V(r) (kJ/mol)  Lennard-Jones V(r) (kJ/mol)
# 2   3.000           0.003055          8.020850                     9.681427
# 3   3.250           0.000518          1.360298                     1.697631
# 4   3.500          -0.000279         -0.732462                    -0.513554
# 5   3.750          -0.000441         -1.157373                    -0.980470
# 7   3.775          -0.000442         -1.160130                    -0.989095
# 8   3.800          -0.000441         -1.158686                    -0.993766
# 9   3.850          -0.000436         -1.145269                    -0.993171
# 10  4.000          -0.000400         -1.049150                    -0.938155
# 11  4.250          -0.000313         -0.822097                    -0.774204
# 13  4.500          -0.000232         -0.609904                    -0.606786
# 14  5.000          -0.000123         -0.322831                    -0.357382
# ...

# %% [markdown]
# ***

# %% [markdown]
# ### Task 3:
# The goal of this task is to visualize the QM target energies and the Lennard-Jones energies as (line) plots.
#
# The x-axis containsthe atom-atom distances $R$ in Å. The y-axis contains the potential energies in kJ/mol.
#
# Both energy columns are plotted in the same diagram so that the QM target data can be directly compared with the Lennard-Jones results.

# %%
ar2_calculations.plot(x='R (Å)', y=['QM V(r) (kJ/mol)', 'Lennard-Jones V(r) (kJ/mol)'], 
                      kind='line', xlabel='Distances R (Å)', ylabel='V(r) (kJ/mol)',
                      title='QM V(r) compared to Lennard-Jones V(r)', fontsize=12).grid('on', which='major', 
                                                                                        axis='y')

# %% [markdown]
# The plot shows that both energy curves are:
# - positive at short distances (3.0 Å),
# - negative at medium distances (3.5 - 6.0 Å),
# - approaching zero at longer distances (6.5 - 7.0 Å).
#
# Overall the Lennard-Jones curve follows the same general shape as the QM target data. However it does not match every value exactly because it is a simplified classical model.

# %% [markdown]
# ***

# %% [markdown]
# ### Task 4:
#
# The goal of this task is to save the final results to a CSV file.
#
# The exported file contains the data columns:
# - the distances $R$ in **Å**,
# - the QM target energies in **Hartree**,
# - the QM target energies in **kJ/mol**,
# - the Lennard-Jones energies in **kJ/mol**.

# %%
ar2_calculations.to_csv('Lennard_Jones_Ar2.csv',
                        sep=',', index=False, encoding='utf-8')

# %% [markdown]
# The below is not necessary for the Assignment, however I will leave it in anyways as a visualization aid.
#
# The saved CSV file is read into python again to the new DataFrame `test_output` to check that the export was successful and that the required columns are still present.

# %%
test_output = pd.read_csv('Lennard_Jones_Ar2.csv', header=0, sep=',')
test_output
# Out:
#     R (Å)  QM V(r) (Hartree)  QM V(r) (kJ/mol)  Lennard-Jones V(r) (kJ/mol)
# 0   3.000           0.003055          8.020850                     9.681427
# 1   3.250           0.000518          1.360298                     1.697631
# 2   3.500          -0.000279         -0.732462                    -0.513554
# 3   3.750          -0.000441         -1.157373                    -0.980470
# 4   3.775          -0.000442         -1.160130                    -0.989095
# 5   3.800          -0.000441         -1.158686                    -0.993766
# 6   3.850          -0.000436         -1.145269                    -0.993171
# 7   4.000          -0.000400         -1.049150                    -0.938155
# 8   4.250          -0.000313         -0.822097                    -0.774204
# 9   4.500          -0.000232         -0.609904                    -0.606786
# 10  5.000          -0.000123         -0.322831                    -0.357382
# ...

# %% [markdown]
# ***

# %% [markdown]
# ### Summary of Results
#
# The QM target data was loaded, cleaned, and converted from Hartree to kJ/mol. The same distance values were then used to compute Lennard-Jones potential energies for Ar$_2$. Afterwards both sets of values were plotted out as a visualization and then the entire DataFrame was saved to a new CSV file to ensure permanence.
#
# At short distances the potential energy is positive, which shows strong repulsion. At larger distances, both energies approach zero. This means that the Lennard-Jones equation captures the overall shape of the Ar$_2$ interaction, but remains an approximation of the QM benchmark data.

# %% [markdown]
# ***

# %% [markdown]
# ## References:
# [1] Cybulski, S. M., & Toczyłowski, R. R. (1999). Ground state potential energy curves for He2, Ne1, Ar2, He-Ne, He-Ar, and Ne-Ar: A Coupled-Cluster Study. Journal of Chemical Physics, 111, 10520-10528.
#
# [2] Wikipedia contributors, ”Hartree.” Wikimedia Foundation. Last modified February 26, 2026. https://en.wikipedia.org/wiki/Hartree. Last access on May 18, 2026.
#
# [3] Wikipedia contributors, ”Lennard-Jones potential.” Wikimedia Foundation. Last modified July 24, 2022. https://en.wikipedia.org/wiki/Lennard-Jones_potential. Last access on May 18, 2026.
#
# [4] Michels, A., Wijker, Hub., & Wijker, Hk. (1949). Isotherms of Argon Between 0°C and 150°C and Pressures Up to 2900 Atmospheres. Physica, 15(7), 627-633.
