# %% [markdown]
# ## SciPro ID: 2026SS_07

# %% [markdown]
# # Homework_5: NumPy Review

# %% [markdown]
# ***

# %% [markdown]
# ### Imports:

# %%
import

# %% [markdown]
# ***

# %% [markdown]
# ## Introduction to the Assignment:
#
# The goal of this assignment ...

# %% [markdown]
# is to do this and that with AI

# %% [markdown]
# ***

# %% [markdown]
# ## ChatGPT Prompt:
#
# The following is the complete prompt i gave ChatGPT using GPT-5.5 with high reasoning capabilites.

# %% [markdown]
# You are my Python and NumPy tutor for a Scientific Programming course.
#
# I need to review NumPy by solving small coding exercises myself.
# Please generate 2 short coding exercises for me, but do not provide the full solutions unless I ask for hints afterward.
#
# The exercises should focus on these topics:
# 1. Basic NumPy array operations, including shape manipulation, indexing, slicing, and filtering.
# 2. A comparison between a standard Python loop and a vectorized NumPy operation using `timeit`.
#
# Requirements:
# - Use only Python built-ins, NumPy, and optionally `timeit`.
# - Make the tasks small enough to solve in a Jupyter notebook.
# - Clearly state the goal of each exercise.
# - Include example input data where needed.
# - Ask me to write the code independently.
# - After each exercise, include 2–3 guiding questions that help me think through the solution without giving it away.
# - Do not write the final code solution unless I explicitly request a hint or feedback.
#
# Format your response like this:
#
# ## Exercise 1: [Title]
# **Topic:**
# **Goal:**
# **Task:**
# **Starter data:**
# **Guiding questions:**
#
# ## Exercise 2: [Title]
# **Topic:**
# **Goal:**
# **Task:**
# **Starter data:**
# **Guiding questions:**

# %% [markdown]
# ## Prompt Result:
#
# The following is what I got returned

# %% [markdown]
# ## Exercise 1: Student Scores Array Practice
#
# **Topic:**
# Basic NumPy array operations: shape manipulation, indexing, slicing, and filtering.
#
# **Goal:**
# Practice creating and manipulating NumPy arrays, selecting specific values, reshaping data, and filtering values based on conditions.
#
# **Task:**
# Create a NumPy array from the starter data below. Then write code that:
#
# 1. Converts the data into a NumPy array.
# 2. Checks the shape of the array.
# 3. Selects the scores of the second student.
# 4. Selects only the scores from the last two assignments.
# 5. Reshapes the array into a one-dimensional array.
# 6. Filters and displays all scores greater than or equal to `80`.
#
# **Starter data:**
#
# ```python id="f9vfs9"
# import numpy as np
#
# scores = [
#     [72, 85, 90],
#     [88, 79, 95],
#     [60, 70, 75],
#     [91, 84, 89]
# ]
# ```
#
# **Guiding questions:**
#
# - What is the difference between `array[1]`, `array[:, 1]`, and `array[1, :]`?
# - Which slicing syntax lets you select the last two columns?
# - How can a Boolean condition like `array >= 80` be used for filtering?
#
#
# ## Exercise 2: Loop vs Vectorized NumPy Performance
#
# **Topic:**
# Comparing a standard Python loop with a vectorized NumPy operation using `timeit`.
#
# **Goal:**
# Understand why NumPy vectorization is usually faster than looping through values manually in Python.
#
# **Task:**
# Create a large NumPy array using the starter data below. Then write two versions of the same calculation:
#
# 1. A standard Python loop that squares every number and stores the results in a list.
# 2. A vectorized NumPy operation that squares the whole array at once.
# 3. Use `timeit` to compare the runtime of both approaches.
# 4. Print or display which approach is faster.
#
# **Starter data:**
#
# ```python id="uletlx"
# import numpy as np
# import timeit
#
# numbers = np.arange(1, 1_000_001)
# ```
#
# **Guiding questions:**
#
# - How would you square each value manually using a `for` loop?
# - What happens when you write `numbers ** 2` directly?
# - Why might NumPy be faster even though both approaches calculate the same result?

# %% [markdown]
# You are my Python and NumPy tutor for a Scientific Programming course.
#
# I need to review NumPy by solving small coding exercises myself. Please generate 2 short coding exercises for me, but do not provide the full solutions unless I ask for hints afterward.
#
# The exercises should focus on these topics:
# 1. Creating, reshaping, slicing, filtering, and concatenating NumPy arrays of different sizes.
# 2. Working with polynomial functions using `numpy.polynomial.polynomial`, including evaluating a polynomial and fitting a polynomial curve to noisy toy data.
#
# Requirements:
# - Use only Python built-ins, NumPy, and optionally Pandas.
# - Keep the exercises suitable for a Jupyter notebook.
# - Provide clear starter data for each exercise.
# - Make the tasks realistic but not too long.
# - Ask me to write the code independently.
# - Include 2–3 guiding questions after each exercise.
# - Do not provide the final solution code unless I explicitly ask for a hint or feedback.
#
# Format your response like this:
#
# ## Exercise 1: [Title]
# **Topic:**
# **Goal:**
# **Task:**
# **Starter data:**
# **Guiding questions:**
#
# ## Exercise 2: [Title]
# **Topic:**
# **Goal:**
# **Task:**
# **Starter data:**
# **Guiding questions:**

# %% [markdown]
# # NumPy Review Exercises
#
# ## Exercise 1: Sensor Data Cleanup and Combination
#
# **Topic:**
# Creating, reshaping, slicing, filtering, and concatenating NumPy arrays of different sizes.
#
# **Goal:**
# Practice building NumPy arrays from raw data, reshaping them into a useful structure, selecting specific parts of the data, filtering values based on conditions, and combining arrays with different lengths.
#
# **Task:**
# You are given temperature measurements from two different sensors. Sensor A recorded 12 values, while Sensor B recorded 8 values.
#
# Write your own code to:
#
# 1. Create NumPy arrays for both sensors.
# 2. Reshape the Sensor A data into a `3 x 4` array.
# 3. Select only the second row of the reshaped Sensor A data.
# 4. Filter all Sensor A values above `22.0`.
# 5. Filter all Sensor B values below `20.0`.
# 6. Concatenate the filtered values from both sensors into one final array.
# 7. Print the shape and contents of each important intermediate result.
#
# **Starter data:**
#
# ```python
# import numpy as np
#
# sensor_a = [19.8, 20.1, 21.5, 22.3,
#             18.9, 19.5, 23.1, 24.0,
#             20.7, 21.2, 22.8, 23.5]
#
# sensor_b = [18.5, 19.2, 20.0, 21.1,
#             17.8, 18.9, 22.4, 23.0]
# ```
#
# **Guiding questions:**
#
# * Which NumPy function can turn a Python list into a NumPy array?
# * After reshaping Sensor A, how can you access only one row?
# * When filtering arrays, what kind of object does the condition `array > value` create?
#
# ---
#
# ## Exercise 2: Polynomial Model for Noisy Measurements
#
# **Topic:**
# Working with polynomial functions using `numpy.polynomial.polynomial`, including evaluating a polynomial and fitting a polynomial curve to noisy toy data.
#
# **Goal:**
# Practice representing a polynomial with coefficients, evaluating it at different x-values, and fitting a polynomial to noisy data using NumPy’s polynomial tools.
#
# **Task:**
# You are given toy measurement data that roughly follows a quadratic trend, but with some noise.
#
# Write your own code to:
#
# 1. Import `polynomial` from `numpy.polynomial`.
# 2. Create an array of x-values.
# 3. Define a polynomial with the coefficients `[2.0, -0.5, 0.25]`.
#
#    * This represents a polynomial of the form:
#      `2.0 - 0.5x + 0.25x²`
# 4. Evaluate this polynomial for all x-values.
# 5. Create or use the given noisy y-values.
# 6. Fit a degree-2 polynomial to the noisy data.
# 7. Evaluate the fitted polynomial on the same x-values.
# 8. Compare the original polynomial values, the noisy values, and the fitted values.
#
# **Starter data:**
#
# ```python
# import numpy as np
# from numpy.polynomial import polynomial as poly
#
# x_values = np.array([-4, -3, -2, -1, 0, 1, 2, 3, 4])
#
# true_coefficients = np.array([2.0, -0.5, 0.25])
#
# noisy_y_values = np.array([8.3, 5.9, 4.1, 2.8, 2.2,
#                            1.7, 2.1, 3.0, 4.4])
# ```
#
# **Guiding questions:**
#
# * In `numpy.polynomial.polynomial`, are coefficients ordered from lowest degree to highest degree, or the other way around?
# * Which function can evaluate a polynomial at given x-values?
# * Which function can fit polynomial coefficients to existing data?
